# %% [markdown]
# # 3.2 Downloading the PM2.5 sample data set (Step-1)

# %% [markdown]
# This Jupyter notebook is used to retrieve sensor data (particulate matter - PM 2.5) from the openSenseMap platform (https://docs.opensensemap.org/) and save it as a CSV file. This dataset will be used in step 2 and step 3 of our exercise to mimic sensor data streams that will be sent to a sensor data broker, which will then forward these messages to applications that have subscribed to data of a specific topic.
#
# You must complete the following 4 tasks in order to successfully download the data to a CSV file:
#
# 1. Find the lat/lon value from Google Maps for the region of Münster, Germany
# 2. Draw/Edit the (Area of Interest) AOI Over Münster, Germany
# 3. Limit the spatial extent of your API request for data to your AOI coordinates (BBOX)
# 4. Fetch PM2.5 readings for 7 days, starting from **15 Jan, 2024**

# %%
## Import Libraries

import requests # for connecting URL of the API endpoints
import geojson # to read geojson files
from geojson import dump
import pandas as pd # to handle tabular data
from ipyleaflet import Map, basemaps, WidgetControl, Marker, basemap_to_tiles, DrawControl, GeoJSON # widget to enable map interactions
from ipywidgets import IntSlider, ColorPicker, jslink # widget to enable map interactions
import geopandas as gpd # to read files with spatial information like raster or vector

# %%
## Defining the Service Endpoints that we'll use

sensebox_url = "https://api.opensensemap.org/boxes?"
sensebox_data_url = "https://api.opensensemap.org/statistics/descriptive?"

phenomenon = "PM2.5"

# %% [markdown]
# ### Load Map Widget
#
# The map widget enables us to perform interactive GIS/Map operations programmatically within the jupyter environment.
# Run the following cell to visualise/test the map widget. The current center of map is [0,0]

# %%
center = (0, 0)

m = Map(center=center, zoom=15)
marker = Marker(location=center, draggable=True)
m.add_layer(marker);
display(m)
# Out:
# Map(center=[0, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text'…

# %% [markdown]
# **By the way:**
# Do you know the name given to this point of zero degrees latitude and zero degrees longitude, i.e., where the prime meridian and the equator intersect?

# %% [markdown]
# ### TASK 1: Find the lat/lon value from Google Maps for the region of Münster, Germany
#
# Head over to https://maps.google.com/. Search or locate to "Münster, Germany". Now, from the **url** in your browser, find the lat/lon values.
#
# *Hint: It should start with "@xx.xxxxxxx,xx.xxxxxxx"*
#
# Copy the two numbers and use it to center the map

# %%
lat =  
lng = 

center = (lat, lng)

m = Map(center=center, zoom=11)
marker = Marker(location=center, draggable=True)
display(m)
# Out:
# Map(center=[51.952187, 7.623206], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', …

# %% [markdown]
# ### TASK 2: Draw/Edit the (Area of Interest) AOI Over Münster, Germany
#
# Our objective is to capture PM2.5 sensors installed in Münster.
# Make sure you cover as much of Münster you can but not too big to slow down the API!

# %%
## Function to save AOI as GeoJSON

feature_collection = {
    'type': 'FeatureCollection',
    'features': []
}

def handle_draw(self, action, geo_json):    
    feature_collection['features'].append(geo_json)

# %%
## Configure draw properties on map

draw_control = DrawControl()
draw_control.rectangle = {
    "shapeOptions": {
        "fillColor": "#fca45d",
        "color": "#fca45d",
        "fillOpacity": 0.5
    }
}

center = (lat, lng)

m = Map(center=center, zoom=11)
marker = Marker(location=center, draggable=True)

m.add_control(draw_control)

draw_control.on_draw(handle_draw)
display(m)
# Out:
# Map(center=[51.952187, 7.623206], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', …

# %%
## Save and display your GeoJSON

munster_aoi = feature_collection

center = (lat, lng)

m = Map(center=center, zoom=11)
marker = Marker(location=center, draggable=True)

geo_json = GeoJSON(
    data=munster_aoi,
    style={
        'opacity': 1, 'dashArray': '9', 'fillOpacity': 0.4, 'weight': 1, 'fillColor': '#fca45d'
    }
)

m.add_layer(geo_json)
display(m)
# Out:
# Map(center=[51.952187, 7.623206], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', …

# %%
## Save the GeoJSON

with open('../data/aoi_opensensemap.geojson', 'w') as f:
    dump(munster_aoi, f)

# %%
## Get the Bounding Box Coordinates of AOI

gdf = gpd.read_file('../data/aoi_opensensemap.geojson')
munster_bbox = map(str, gdf.total_bounds)

# %% [markdown]
# ### Get Senseboxes Installed in Münster, Germany

# %%
## Convert bbox coordinates to string representation
geometry = map(str, munster_bbox)

# %%
## DEFINE PARAMETERS ##

from_date = "2024-01-01T00:00:00.000Z"
bbox_geometry = ','.join(geometry)

# %% [markdown]
# ### TASK 3: Limit the spatial extent of your API request for data to your AOI coordinates (BBOX)
#
# Add the bbox parameter after "+" sign

# %%
sensebox_url_params = "date="+from_date+"&phenomenon="+phenomenon+"&bbox="+

# %%
## Define URL endpoint

pull_senseboxes_url = sensebox_url+sensebox_url_params

# %% [markdown]
# Final url should look something like this
#
# *https://api.opensensemap.org/boxes?date=2024-01-01T00:00:00.000Z&phenomenon=PM2.5&bbox=7.547844,51.907801,7.689313,51.999208*

# %%
response = requests.get(pull_senseboxes_url)
json_output = response.json()

## We'll use only 10 senseboxes to limit the amount of data
json_output = json_output[:10]
json_output

# retrieving the sensebox data may take some time (30 seconds to some minutes, depending on the network and server workload)..
# Out:
# [{'_id': '591f578c51d34600116a8ea5',
#   'createdAt': '2022-03-30T11:25:43.288Z',
#   'updatedAt': '2024-08-20T18:15:03.963Z',
#   'name': 'Wetterstation Erpho',
#   'exposure': 'outdoor',
#   'model': 'homeWifiFeinstaub',
#   'sensors': [{'title': 'Temperatur',
#     'unit': '°C',
#     'sensorType': 'HDC1008',
#     'icon': 'osem-thermometer',
#     '_id': '591f578c51d34600116a8ea6',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:03.954Z',
#      'value': '25.87'}},
#    {'title': 'rel. Luftfeuchte',
#     'unit': '%',
#     'sensorType': 'HDC1008',
#     'icon': 'osem-humidity',
#     '_id': '591f578c51d34600116a8ea7',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:03.954Z',
#      'value': '62.08'}},
#    {'title': 'Luftdruck',
#     'unit': 'hPa',
#     'sensorType': 'BMP280',
#     'icon': 'osem-barometer',
#     '_id': '591f578c51d34600116a8ea8',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:03.954Z',
#      'value': '1002.20'}},
#    {'title': 'Beleuchtungsstärke',
#     'unit': 'lx',
#     'sensorType': 'TSL45315',
#     'icon': 'osem-brightness',
#     '_id': '591f578c51d34600116a8ea9',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:03.954Z',
#      'value': '68.00'}},
#    {'title': 'UV-Intensität',
#     'unit': 'μW/cm²',
#     'sensorType': 'VEML6070',
#     'icon': 'osem-brightness',
#     '_id': '591f578c51d34600116a8eaa',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:03.954Z',
#      'value': '0.00'}},
#    {'_id': '5923371251d3460011906244',
#     'icon': 'osem-brightness',
#     'sensorType': 'VEML6070',
#     'unit': '-',
#     'title': 'UV-Index',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:03.954Z',
#      'value': '0.00'}},
#    {'title': 'PM10',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '59456e66a4ad590011177282',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:03.954Z',
#      'value': '19.90'}},
#    {'title': 'PM2.5',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '59458624a4ad590011186665',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:03.954Z',
#      'value': '8.50'}},
#    {'_id': '594838afa4ad59001133dd62',
#     'icon': 'osem-particulate-matter',
#     'sensorType': 'WS',
#     'unit': 'km/h',
#     'title': 'Windgeschwindigkeit',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:03.954Z',
#      'value': '0.00'}},
#    {'_id': '594838afa4ad59001133dd63',
#     'icon': 'osem-particulate-matter',
#     'sensorType': 'WS',
#     'unit': 'km/h',
#     'title': 'Windböen',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:03.954Z',
#      'value': '0.00'}},
#    {'_id': '594838afa4ad59001133dd64',
#     'icon': 'osem-particulate-matter',
#     'sensorType': 'WS',
#     'unit': '°',
#     'title': 'Windrichtung',
#     'lastMeasurement': {'value': '220.67',
#      'createdAt': '2024-01-01T03:59:55.970Z'}},
#    {'_id': '594838afa4ad59001133dd65',
#     'icon': 'osem-sprinkles',
#     'sensorType': 'WS',
#     'unit': 'mm/m²',
#     'title': 'Niederschlag',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:03.954Z',
#      'value': '0.00'}}],
#   'description': '- TESTBETRIEB -',
#   'currentLocation': {'coordinates': [7.645218, 51.96422],
#    'type': 'Point',
#    'timestamp': '2017-05-19T20:37:32.000Z'},
#   'lastMeasurementAt': '2024-08-20T18:15:03.954Z',
#   'grouptag': [''],
#   'loc': [{'geometry': {'coordinates': [7.645218, 51.96422],
#      'type': 'Point',
#      'timestamp': '2017-05-19T20:37:32.000Z'},
#     'type': 'Feature'}]},
#  {'_id': '59ad958fd67eb50011b85f6d',
#   'createdAt': '2022-03-30T11:25:43.366Z',
#   'updatedAt': '2024-08-20T18:14:32.068Z',
#   'name': 'Kortumweg',
#   'exposure': 'outdoor',
#   'sensors': [{'title': 'PM10',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '59ad958fd67eb50011b85f71',
#     'lastMeasurement': {'value': '27.73',
#      'createdAt': '2024-01-01T03:59:56.244Z'}},
#    {'title': 'PM2.5',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '59ad958fd67eb50011b85f70',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:32.061Z',
#      'value': '222.00'}},
#    {'title': 'Temperatur',
#     'unit': '°C',
#     'sensorType': 'DHT22',
#     'icon': 'osem-thermometer',
#     '_id': '59ad958fd67eb50011b85f6f',
#     'lastMeasurement': None},
#    {'title': 'rel. Luftfeuchte',
#     'unit': '%',
#     'sensorType': 'DHT22',
#     'icon': 'osem-humidity',
#     '_id': '59ad958fd67eb50011b85f6e',
#     'lastMeasurement': None}],
#   'model': 'luftdaten_sds011_dht22',
#   'currentLocation': {'coordinates': [7.635283, 51.903004],
#    'type': 'Point',
#    'timestamp': '2017-09-04T18:03:59.000Z'},
#   'lastMeasurementAt': '2024-08-20T18:14:32.061Z',
#   'grouptag': [''],
#   'loc': [{'geometry': {'coordinates': [7.635283, 51.903004],
#      'type': 'Point',
#      'timestamp': '2017-09-04T18:03:59.000Z'},
#     'type': 'Feature'}]},
#  {'_id': '5a0c347b9fd3c2001111b701',
#   'createdAt': '2022-03-30T11:25:43.427Z',
#   'updatedAt': '2024-08-20T18:14:24.870Z',
#   'name': 'VennheideBox',
#   'currentLocation': {'type': 'Point',
#    'coordinates': [7.620606, 51.921065],
#    'timestamp': '2024-07-17T13:00:28.527Z'},
#   'grouptag': ['ifgi'],
#   'exposure': 'outdoor',
#   'sensors': [{'title': 'Temperatur',
#     'unit': '°C',
#     'sensorType': 'HDC1008',
#     'icon': 'osem-thermometer',
#     '_id': '5a0c347b9fd3c2001111b708',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:24.863Z',
#      'value': '24.47'}},
#    {'title': 'rel. Luftfeuchte',
#     'unit': '%',
#     'sensorType': 'HDC1008',
#     'icon': 'osem-humidity',
#     '_id': '5a0c347b9fd3c2001111b707',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:24.863Z',
#      'value': '91.33'}},
#    {'title': 'Luftdruck',
#     'unit': 'hPa',
#     'sensorType': 'BMP280',
#     'icon': 'osem-barometer',
#     '_id': '5a0c347b9fd3c2001111b706',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:24.863Z',
#      'value': '1003.50'}},
#    {'title': 'Beleuchtungsstärke',
#     'unit': 'lx',
#     'sensorType': 'TSL45315',
#     'icon': 'osem-brightness',
#     '_id': '5a0c347b9fd3c2001111b705',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:24.863Z',
#      'value': '36.00'}},
#    {'title': 'UV-Intensität',
#     'unit': 'μW/cm²',
#     'sensorType': 'VEML6070',
#     'icon': 'osem-brightness',
#     '_id': '5a0c347b9fd3c2001111b704',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:24.863Z',
#      'value': '0.00'}},
#    {'title': 'PM10',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5a0c347b9fd3c2001111b703',
#     'lastMeasurement': {'value': '8.10',
#      'createdAt': '2024-01-01T03:59:17.662Z'}},
#    {'title': 'PM2.5',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5a0c347b9fd3c2001111b702',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:24.863Z',
#      'value': '10.40'}}],
#   'model': 'homeEthernetFeinstaub',
#   'image': '5a0c347b9fd3c2001111b701_sgrqrp.jpg',
#   'lastMeasurementAt': '2024-08-20T18:14:24.863Z',
#   'description': 'senseBox is mounted under the canopy roof',
#   'loc': [{'geometry': {'type': 'Point',
#      'coordinates': [7.620606, 51.921065],
#      'timestamp': '2024-07-17T13:00:28.527Z'},
#     'type': 'Feature'}]},
#  {'_id': '5abd221b850005001b1aff35',
#   'createdAt': '2022-03-30T11:25:43.516Z',
#   'updatedAt': '2024-08-20T18:14:00.978Z',
#   'name': 'Feinstaub_MS_PIUSALLEE',
#   'currentLocation': {'timestamp': '2018-03-29T17:27:55.199Z',
#    'coordinates': [7.64153, 51.973023, 6],
#    'type': 'Point'},
#   'grouptag': ['Feinstaub'],
#   'exposure': 'outdoor',
#   'sensors': [{'title': 'PM10',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5abd221b850005001b1aff39',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:00.971Z',
#      'value': '183.27'}},
#    {'title': 'PM2.5',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5abd221b850005001b1aff38',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:00.971Z',
#      'value': '63.17'}},
#    {'title': 'Temperatur',
#     'unit': '°C',
#     'sensorType': 'DHT22',
#     'icon': 'osem-thermometer',
#     '_id': '5abd221b850005001b1aff37',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:00.971Z',
#      'value': '25.30'}},
#    {'title': 'rel. Luftfeuchte',
#     'unit': '%',
#     'sensorType': 'DHT22',
#     'icon': 'osem-humidity',
#     '_id': '5abd221b850005001b1aff36',
#     'lastMeasurement': {'value': '90.30',
#      'createdAt': '2024-01-01T03:59:55.201Z'}}],
#   'model': 'luftdaten_sds011_dht22',
#   'lastMeasurementAt': '2024-08-20T18:14:00.971Z',
#   'loc': [{'geometry': {'timestamp': '2018-03-29T17:27:55.199Z',
#      'coordinates': [7.64153, 51.973023, 6],
#      'type': 'Point'},
#     'type': 'Feature'}]},
#  {'_id': '5acfae2a223bd8001977b61e',
#   'createdAt': '2022-03-30T11:25:43.522Z',
#   'updatedAt': '2024-08-20T18:14:55.228Z',
#   'name': 'PGKN FS03',
#   'currentLocation': {'timestamp': '2018-04-12T19:06:18.499Z',
#    'coordinates': [7.646677, 51.988501],
#    'type': 'Point'},
#   'grouptag': ['PGKN'],
#   'exposure': 'outdoor',
#   'sensors': [{'title': 'PM10',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5acfae2a223bd8001977b622',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:54.807Z',
#      'value': '10.38'}},
#    {'title': 'PM2.5',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5acfae2a223bd8001977b621',
#     'lastMeasurement': {'value': '2.67',
#      'createdAt': '2024-01-01T03:59:07.460Z'}},
#    {'title': 'Temperatur',
#     'unit': '°C',
#     'sensorType': 'DHT22',
#     'icon': 'osem-thermometer',
#     '_id': '5acfae2a223bd8001977b620',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:54.807Z',
#      'value': '21.90'}},
#    {'title': 'rel. Luftfeuchte',
#     'unit': '%',
#     'sensorType': 'DHT22',
#     'icon': 'osem-humidity',
#     '_id': '5acfae2a223bd8001977b61f',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:14:54.807Z',
#      'value': '99.90'}}],
#   'model': 'luftdaten_sds011_dht22',
#   'description': 'Garten, Richtung Osten, außer früh morgens beschattet',
#   'lastMeasurementAt': '2024-08-20T18:14:54.807Z',
#   'loc': [{'geometry': {'timestamp': '2018-04-12T19:06:18.499Z',
#      'coordinates': [7.646677, 51.988501],
#      'type': 'Point'},
#     'type': 'Feature'}]},
#  {'_id': '5b3e7f6f5dc1ec001be11cf1',
#   'createdAt': '2022-03-30T11:25:43.556Z',
#   'updatedAt': '2024-08-20T18:15:00.886Z',
#   'name': 'U6B GTÜ SSH Bölling & Partner',
#   'currentLocation': {'type': 'Point',
#    'coordinates': [7.569078, 51.994149],
#    'timestamp': '2018-07-06T10:14:38.261Z'},
#   'grouptag': ['Feinstaub'],
#   'exposure': 'outdoor',
#   'sensors': [{'title': 'PM10',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5b3e7f6f5dc1ec001be11cf6',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:00.759Z',
#      'value': '17.53'}},
#    {'title': 'PM2.5',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5b3e7f6f5dc1ec001be11cf5',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:00.759Z',
#      'value': '8.73'}},
#    {'title': 'Temperatur',
#     'unit': '°C',
#     'sensorType': 'BME280',
#     'icon': 'osem-thermometer',
#     '_id': '5b3e7f6f5dc1ec001be11cf4',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:00.759Z',
#      'value': '20.70'}},
#    {'title': 'rel. Luftfeuchte',
#     'unit': '%',
#     'sensorType': 'BME280',
#     'icon': 'osem-humidity',
#     '_id': '5b3e7f6f5dc1ec001be11cf3',
#     'lastMeasurement': {'value': '100.00',
#      'createdAt': '2024-01-01T03:57:39.269Z'}},
#    {'title': 'Luftdruck',
#     'unit': 'Pa',
#     'sensorType': 'BME280',
#     'icon': 'osem-barometer',
#     '_id': '5b3e7f6f5dc1ec001be11cf2',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:15:00.759Z',
#      'value': '100140.47'}}],
#   'model': 'luftdaten_sds011_bme280',
#   'lastMeasurementAt': '2024-08-20T18:15:00.759Z',
#   'loc': [{'geometry': {'type': 'Point',
#      'coordinates': [7.569078, 51.994149],
#      'timestamp': '2018-07-06T10:14:38.261Z'},
#     'type': 'Feature'}]},
#  {'_id': '5d6e465a953683001a2b62c5',
#   'createdAt': '2022-03-30T11:25:43.760Z',
#   'updatedAt': '2024-08-20T18:14:32.775Z',
#   'name': 'Bundeskanzleramt',
#   'currentLocation': {'type': 'Point',
#    'coordinates': [13.369128, 52.520151],
#    'timestamp': '2019-09-03T11:34:51.524Z'},
#   'exposure': 'outdoor',
#   'sensors': [{'title': 'Temperatur',
#     'unit': '°C',
#     'sensorType': 'HDC1080',
#     'icon': 'osem-thermometer',
#     '_id': '5d6e465a953683001a2b62cc',
#     'lastMeasurement': {'value': '26.4',
#      'createdAt': '2024-08-20T18:14:32.000Z'}},
#    {'title': 'rel. Luftfeuchte',
#     'unit': '%',
#     'sensorType': 'HDC1080',
#     'icon': 'osem-humidity',
#     '_id': '5d6e465a953683001a2b62cb',
#     'lastMeasurement': {'value': '92.4',
#      'createdAt': '2024-01-01T03:59:33.088Z'}},
#    {'title': 'Luftdruck',
#     'unit': 'hPa',
#     'sensorType': 'BMP280',
#     'icon': 'osem-barometer',
#     '_id': '5d6e465a953683001a2b62ca',
#     'lastMeasurement': {'value': '1005.7',
#      'createdAt': '2024-08-20T18:14:32.000Z'}},
#    {'title': 'Beleuchtungsstärke',
#     'unit': 'lx',
#     'sensorType': 'TSL45315',
#     'icon': 'osem-brightness',
#     '_id': '5d6e465a953683001a2b62c9',
#     'lastMeasurement': {'value': '412',
#      'createdAt': '2024-08-20T18:14:32.000Z'}},
#    {'title': 'UV-Intensität',
#     'unit': 'μW/cm²',
#     'sensorType': 'VEML6070',
#     'icon': 'osem-brightness',
#     '_id': '5d6e465a953683001a2b62c8',
#     'lastMeasurement': {'value': '22',
#      'createdAt': '2024-08-20T18:14:32.000Z'}},
#    {'title': 'PM10',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5d6e465a953683001a2b62c7',
#     'lastMeasurement': {'value': '6.5',
#      'createdAt': '2024-08-20T18:14:32.000Z'}},
#    {'title': 'PM2.5',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5d6e465a953683001a2b62c6',
#     'lastMeasurement': {'value': '1.9',
#      'createdAt': '2024-08-20T18:14:32.000Z'}}],
#   'model': 'homeV2Lora',
#   'grouptag': ['Futurium'],
#   'lastMeasurementAt': '2024-08-20T18:14:32.000Z',
#   'image': '5d6e465a953683001a2b62c5_qeu9mi.jpg',
#   'description': 'Diese senseBox wurde Herrn Braun bei der Eröffnung des Zukunftsmuseums Futurium in Berlin überreicht. Die senseBox ist Teil des Berliner Futurium-Messnetz und überträgt ihre Daten über LoRaWAN (TTN). Ein interaktiver Tisch mit einer Projektion der Karte von Berlin stellt die Live-Umweltdaten dar.',
#   'weblink': 'https://futurium.de/de/sense-box',
#   'loc': [{'geometry': {'type': 'Point',
#      'coordinates': [13.369128, 52.520151],
#      'timestamp': '2019-09-03T11:34:51.524Z'},
#     'type': 'Feature'}]},
#  {'_id': '5d91f4bb5f3de0001ab6bb78',
#   'createdAt': '2022-03-30T11:25:43.769Z',
#   'updatedAt': '2024-08-15T11:56:56.707Z',
#   'name': 'Reedu GmbH & Co. KG',
#   'currentLocation': {'timestamp': '2019-09-30T12:27:39.541Z',
#    'coordinates': [7.631939, 51.954339],
#    'type': 'Point'},
#   'exposure': 'outdoor',
#   'sensors': [{'title': 'Temperatur',
#     'unit': '°C',
#     'sensorType': 'HDC1080',
#     'icon': 'osem-thermometer',
#     '_id': '5d91f4bb5f3de0001ab6bb7f',
#     'lastMeasurement': {'value': '28.4',
#      'createdAt': '2024-08-15T11:56:56.000Z'}},
#    {'title': 'rel. Luftfeuchte',
#     'unit': '%',
#     'sensorType': 'HDC1080',
#     'icon': 'osem-humidity',
#     '_id': '5d91f4bb5f3de0001ab6bb7e',
#     'lastMeasurement': {'value': '57.6',
#      'createdAt': '2024-08-15T11:56:56.000Z'}},
#    {'title': 'Luftdruck',
#     'unit': 'hPa',
#     'sensorType': 'BMP280',
#     'icon': 'osem-barometer',
#     '_id': '5d91f4bb5f3de0001ab6bb7d',
#     'lastMeasurement': {'value': '1007.4',
#      'createdAt': '2024-08-15T11:56:56.000Z'}},
#    {'title': 'Beleuchtungsstärke',
#     'unit': 'lx',
#     'sensorType': 'TSL45315',
#     'icon': 'osem-brightness',
#     '_id': '5d91f4bb5f3de0001ab6bb7c',
#     'lastMeasurement': {'value': '5296',
#      'createdAt': '2024-08-15T11:56:56.000Z'}},
#    {'title': 'UV-Intensität',
#     'unit': 'μW/cm²',
#     'sensorType': 'VEML6070',
#     'icon': 'osem-brightness',
#     '_id': '5d91f4bb5f3de0001ab6bb7b',
#     'lastMeasurement': {'value': '253',
#      'createdAt': '2024-08-15T11:56:56.000Z'}},
#    {'title': 'PM10',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5d91f4bb5f3de0001ab6bb7a',
#     'lastMeasurement': {'value': '7.2',
#      'createdAt': '2024-08-15T11:56:56.000Z'}},
#    {'title': 'PM2.5',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5d91f4bb5f3de0001ab6bb79',
#     'lastMeasurement': {'value': '0.7',
#      'createdAt': '2024-01-01T03:59:23.000Z'}}],
#   'model': 'homeV2Lora',
#   'lastMeasurementAt': '2024-08-15T11:56:56.000Z',
#   'image': '5d91f4bb5f3de0001ab6bb78_r36apq.jpg',
#   'grouptag': [''],
#   'loc': [{'geometry': {'timestamp': '2019-09-30T12:27:39.541Z',
#      'coordinates': [7.631939, 51.954339],
#      'type': 'Point'},
#     'type': 'Feature'}]},
#  {'_id': '5e98843845f937001cf26c6d',
#   'createdAt': '2022-03-30T11:25:43.844Z',
#   'updatedAt': '2024-08-20T18:11:46.905Z',
#   'name': 'Nienberge Garten',
#   'currentLocation': {'timestamp': '2020-04-16T16:13:44.443Z',
#    'coordinates': [7.543988, 51.993367],
#    'type': 'Point'},
#   'exposure': 'outdoor',
#   'sensors': [{'title': 'Temperatur',
#     'unit': '°C',
#     'sensorType': 'HDC1080',
#     'icon': 'osem-thermometer',
#     '_id': '5e98843845f937001cf26c74',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:11:46.901Z',
#      'value': '26.56'}},
#    {'title': 'rel. Luftfeuchte',
#     'unit': '%',
#     'sensorType': 'HDC1080',
#     'icon': 'osem-humidity',
#     '_id': '5e98843845f937001cf26c73',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:11:46.901Z',
#      'value': '64.87'}},
#    {'title': 'Luftdruck',
#     'unit': 'hPa',
#     'sensorType': 'BMP280',
#     'icon': 'osem-barometer',
#     '_id': '5e98843845f937001cf26c72',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:11:46.901Z',
#      'value': '1001.12'}},
#    {'title': 'Beleuchtungsstärke',
#     'unit': 'lx',
#     'sensorType': 'TSL45315',
#     'icon': 'osem-brightness',
#     '_id': '5e98843845f937001cf26c71',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:11:46.901Z',
#      'value': '216.00'}},
#    {'title': 'UV-Intensität',
#     'unit': 'μW/cm²',
#     'sensorType': 'VEML6070',
#     'icon': 'osem-brightness',
#     '_id': '5e98843845f937001cf26c70',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:11:46.901Z',
#      'value': '11.25'}},
#    {'title': 'PM10',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5e98843845f937001cf26c6f',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:11:46.901Z',
#      'value': '19.00'}},
#    {'title': 'PM2.5',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5e98843845f937001cf26c6e',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:11:46.901Z',
#      'value': '15.00'}},
#    {'_id': '5f0ed1eb987fd4001b9939e3',
#     'icon': 'osem-particulate-matter',
#     'sensorType': 'WINDSPEED',
#     'unit': '(m/s)',
#     'title': 'Windgeschwindigkeit',
#     'lastMeasurement': {'value': '42.53',
#      'createdAt': '2024-01-01T03:59:50.692Z'}}],
#   'model': 'homeV2WifiFeinstaub',
#   'lastMeasurementAt': '2024-08-20T18:11:46.901Z',
#   'description': 'senseBox hängt auf Höhe 220cm an der Nordseite einer Gartenhütte aus Holz.\nsenseBox is mounted 220cm above ground at the north side of a wooden garden hut.',
#   'image': '5e98843845f937001cf26c6d_qdiwyt.jpg',
#   'grouptag': [''],
#   'loc': [{'geometry': {'timestamp': '2020-04-16T16:13:44.443Z',
#      'coordinates': [7.543988, 51.993367],
#      'type': 'Point'},
#     'type': 'Feature'}]},
#  {'_id': '5f4542b8badf01001bd5cf24',
#   'createdAt': '2020-08-25T16:56:24.420Z',
#   'updatedAt': '2024-08-20T18:13:19.471Z',
#   'name': 'Lufdaten.info',
#   'currentLocation': {'type': 'Point',
#    'coordinates': [7.723412, 51.910651, 48],
#    'timestamp': '2021-01-30T19:34:54.008Z'},
#   'exposure': 'outdoor',
#   'sensors': [{'title': 'PM10',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5f4542b8badf01001bd5cf29',
#     'lastMeasurement': {'createdAt': '2024-08-01T11:30:36.329Z',
#      'value': '5.70'}},
#    {'title': 'PM2.5',
#     'unit': 'µg/m³',
#     'sensorType': 'SDS 011',
#     'icon': 'osem-cloud',
#     '_id': '5f4542b8badf01001bd5cf28',
#     'lastMeasurement': {'createdAt': '2024-08-01T11:30:36.329Z',
#      'value': '4.80'}},
#    {'title': 'Temperatur',
#     'unit': '°C',
#     'sensorType': 'BME280',
#     'icon': 'osem-thermometer',
#     '_id': '5f4542b8badf01001bd5cf27',
#     'lastMeasurement': {'value': '7.37',
#      'createdAt': '2024-01-01T03:59:50.260Z'}},
#    {'title': 'rel. Luftfeuchte',
#     'unit': '%',
#     'sensorType': 'BME280',
#     'icon': 'osem-humidity',
#     '_id': '5f4542b8badf01001bd5cf26',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:13:19.467Z',
#      'value': '70.81'}},
#    {'title': 'Luftdruck',
#     'unit': 'Pa',
#     'sensorType': 'BME280',
#     'icon': 'osem-barometer',
#     '_id': '5f4542b8badf01001bd5cf25',
#     'lastMeasurement': {'createdAt': '2024-08-20T18:13:19.467Z',
#      'value': '100262.63'}}],
#   'model': 'luftdaten_sds011_bme280',
#   'lastMeasurementAt': '2024-08-20T18:13:19.467Z',
#   'description': 'Sensoren:\nTyp: BME280\nTyp: SDS 011',
#   'loc': [{'geometry': {'type': 'Point',
#      'coordinates': [7.723412, 51.910651, 48],
#      'timestamp': '2021-01-30T19:34:54.008Z'},
#     'type': 'Feature'}]}]

# %%
senseboxes_list = []
sensebox_coords = {}

## Extract the IDs of the senseboxes

for sensebox in json_output:
    senseboxes_list.append(sensebox['_id'])
    coordinates = sensebox['loc'][0]['geometry']['coordinates']
    sensebox_coords[sensebox['_id']] = coordinates[:2]

# %%
## Check the sensebox id numbers
senseboxes_list
# Out:
# ['591f578c51d34600116a8ea5',
#  '59ad958fd67eb50011b85f6d',
#  '5a0c347b9fd3c2001111b701',
#  '5abd221b850005001b1aff35',
#  '5acfae2a223bd8001977b61e',
#  '5b3e7f6f5dc1ec001be11cf1',
#  '5d6e465a953683001a2b62c5',
#  '5d91f4bb5f3de0001ab6bb78',
#  '5e98843845f937001cf26c6d',
#  '5f4542b8badf01001bd5cf24']

# %%
## Check locations of senseboxes
sensebox_coords = pd.DataFrame(sensebox_coords).T.reset_index()
sensebox_coords.rename(columns={'index': 'sensorId', 0: 'lon', 1: 'lat'}, inplace=True)
sensebox_coords
# Out:
#                    sensorId        lon        lat
# 0  591f578c51d34600116a8ea5   7.645218  51.964220
# 1  59ad958fd67eb50011b85f6d   7.635283  51.903004
# 2  5a0c347b9fd3c2001111b701   7.620606  51.921065
# 3  5abd221b850005001b1aff35   7.641530  51.973023
# 4  5acfae2a223bd8001977b61e   7.646677  51.988501
# 5  5b3e7f6f5dc1ec001be11cf1   7.569078  51.994149
# 6  5d6e465a953683001a2b62c5  13.369128  52.520151
# 7  5d91f4bb5f3de0001ab6bb78   7.631939  51.954339
# 8  5e98843845f937001cf26c6d   7.543988  51.993367
# 9  5f4542b8badf01001bd5cf24   7.723412  51.910651

# %% [markdown]
# ### Get PM2.5 Sensor Readings for the Senseboxes

# %%
## Define parameters for the new endpoint

senseboxes_list = ','.join(senseboxes_list)
operation = "arithmeticMean" ## Perform a mean for all values in the duration of "window" timeframe
window = "90000000" ## time in ms. Default: 25 hours
output_format = "tidy" ## Clean CSV Format

# %% [markdown]
# ### TASK 4: Fetch PM2.5 readings for 7 days, starting from 15 Jan, 2024
#
# The format of timestamp should be in **RFC 3339** notation. For eg: *2024-01-15T00:00:00.000Z*
#
# Note: from_date and to_date is inclusive
#
# It is understood that the time range defined here is older and hence not real-time anymore, however, if we had the ability to pull data that was generated few seconds ago, the functionality would still be the same and it would still be "near real-time app"

# %%
from_date = 
to_date =

# %%
sensebox_data_url_params = "boxId="+senseboxes_list+"&from-date="+from_date+"&to-date="+to_date+"&phenomenon="+phenomenon+"&operation="+operation+"&window="+window+"&format="+output_format+"&columns=boxId,boxName,phenomenon,sensorType,unit"

# %%
## Define URL endpoint

pull_readings_url = sensebox_data_url+sensebox_data_url_params
pull_readings_url
# Out:
# 'https://api.opensensemap.org/statistics/descriptive?boxId=591f578c51d34600116a8ea5,59ad958fd67eb50011b85f6d,5a0c347b9fd3c2001111b701,5abd221b850005001b1aff35,5acfae2a223bd8001977b61e,5b3e7f6f5dc1ec001be11cf1,5d6e465a953683001a2b62c5,5d91f4bb5f3de0001ab6bb78,5e98843845f937001cf26c6d,5f4542b8badf01001bd5cf24&from-date=2024-01-15T00:00:00.000Z&to-date=2024-01-22T00:00:00.000Z&phenomenon=PM2.5&operation=arithmeticMean&window=90000000&format=tidy&columns=boxId,boxName,phenomenon,sensorType,unit'

# %% [markdown]
# Final url should look something like this
#
# https://api.opensensemap.org/statistics/descriptive?boxId=5750220bed08f9680c6b4154,591f578c51d34600116a8ea5,599180be7e280a001044b837,59c67b5ed67eb50011666dbb,5a0c15289fd3c200110f3d33&from-date=2022-01-15T00:00:00.000Z&to-date=2022-01-21T00:00:00.000Z&phenomenon=PM2.5&operation=arithmeticMean&window=86400000&format=tidy&columns=boxId,boxName,exposure,height,lat,lon,phenomenon,sensorType,unit

# %%
df = pd.read_csv(pull_readings_url)
df.head()
# again: retrieving the sensebox data may take some time (30 seconds to some minutes, depending on the network and server workload)..
# Out:
#                    sensorId                     boxId              boxName  \
# 0  59458624a4ad590011186665  591f578c51d34600116a8ea5  Wetterstation Erpho
# 1  59458624a4ad590011186665  591f578c51d34600116a8ea5  Wetterstation Erpho
# 2  59458624a4ad590011186665  591f578c51d34600116a8ea5  Wetterstation Erpho
# 3  59458624a4ad590011186665  591f578c51d34600116a8ea5  Wetterstation Erpho
# 4  59458624a4ad590011186665  591f578c51d34600116a8ea5  Wetterstation Erpho
#
#   phenomenon sensorType   unit                time_start  \
# 0      PM2.5    SDS 011  µg/m³  2024-01-14T11:00:00.000Z
# 1      PM2.5    SDS 011  µg/m³  2024-01-15T12:00:00.000Z
# 2      PM2.5    SDS 011  µg/m³  2024-01-16T13:00:00.000Z
# 3      PM2.5    SDS 011  µg/m³  2024-01-17T14:00:00.000Z
# 4      PM2.5    SDS 011  µg/m³  2024-01-18T15:00:00.000Z
#
#    arithmeticMean_90000000
# 0                11.232186
# 1                 4.779400
# 2                 6.492572
# 3                 9.893489
# 4                10.077617

# %%
## Check how many values were received for each day

df['time_start'].value_counts()
# Out:
# time_start
# 2024-01-15T12:00:00.000Z    10
# 2024-01-16T13:00:00.000Z    10
# 2024-01-17T14:00:00.000Z    10
# 2024-01-18T15:00:00.000Z    10
# 2024-01-14T11:00:00.000Z     9
# 2024-01-19T16:00:00.000Z     9
# 2024-01-20T17:00:00.000Z     9
# 2024-01-21T18:00:00.000Z     9
# 2024-01-22T19:00:00.000Z     9
# Name: count, dtype: int64

# %%
## Check how many senseboxes returned values

df['boxId'].value_counts()
# Out:
# boxId
# 591f578c51d34600116a8ea5    9
# 59ad958fd67eb50011b85f6d    9
# 5a0c347b9fd3c2001111b701    9
# 5abd221b850005001b1aff35    9
# 5acfae2a223bd8001977b61e    9
# 5b3e7f6f5dc1ec001be11cf1    9
# 5d6e465a953683001a2b62c5    9
# 5d91f4bb5f3de0001ab6bb78    9
# 5f4542b8badf01001bd5cf24    9
# 5e98843845f937001cf26c6d    4
# Name: count, dtype: int64

# %%
## Rename columns appropriately

df.rename(columns={'time_start': 'day', 'arithmeticMean_90000000': 'value'}, inplace=True)

# %%
## Get location of senseboxes and fetch other senseboxes without values

stream_data = sensebox_coords.merge(df, left_on='sensorId', right_on='boxId', how='left')
stream_data.head()
# Out:
#                  sensorId_x       lon       lat                sensorId_y  \
# 0  591f578c51d34600116a8ea5  7.645218  51.96422  59458624a4ad590011186665
# 1  591f578c51d34600116a8ea5  7.645218  51.96422  59458624a4ad590011186665
# 2  591f578c51d34600116a8ea5  7.645218  51.96422  59458624a4ad590011186665
# 3  591f578c51d34600116a8ea5  7.645218  51.96422  59458624a4ad590011186665
# 4  591f578c51d34600116a8ea5  7.645218  51.96422  59458624a4ad590011186665
#
#                       boxId              boxName phenomenon sensorType   unit  \
# 0  591f578c51d34600116a8ea5  Wetterstation Erpho      PM2.5    SDS 011  µg/m³
# 1  591f578c51d34600116a8ea5  Wetterstation Erpho      PM2.5    SDS 011  µg/m³
# 2  591f578c51d34600116a8ea5  Wetterstation Erpho      PM2.5    SDS 011  µg/m³
# 3  591f578c51d34600116a8ea5  Wetterstation Erpho      PM2.5    SDS 011  µg/m³
# 4  591f578c51d34600116a8ea5  Wetterstation Erpho      PM2.5    SDS 011  µg/m³
#
#                         day      value
# 0  2024-01-14T11:00:00.000Z  11.232186
# 1  2024-01-15T12:00:00.000Z   4.779400
# 2  2024-01-16T13:00:00.000Z   6.492572
# 3  2024-01-17T14:00:00.000Z   9.893489
# 4  2024-01-18T15:00:00.000Z  10.077617

# %% [markdown]
# Save the file as CSV

# %%
stream_data.to_csv('../data/sample_multilocation.csv')

# %% [markdown]
# At the point you should have a file saved by the name **sample_multilocation.csv** in the **data/** folder and this marks the end of STEP-1 of 3 for our worflow

# %% [markdown]
# #### END STEP - 1
